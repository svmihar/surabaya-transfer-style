# %%
import subprocess
import sys

# %%
STYLE_IMAGE='wave_off.jpg'
CONTENT_IMAGE='examples/inputs/surabaya.jpg'
STYLE_WEIGHT='5e2'
STYLE_SCALE='1.0'
STYLE_WEIGHT='2500'

# %%
process1 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -style_scale {STYLE_SCALE} \
  -print_iter 10 \
  -style_weight {STYLE_WEIGHT} \
  -image_size 256 \
  -output_image out1.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn -cudnn_autotune'], shell=True, stdout=subprocess.PIPE)

# %%
process2 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out1.png \
  -style_scale $STYLE_SCALE \
  -print_iter 1 \
  -style_weight $STYLE_WEIGHT \
  -image_size 512 \
  -num_iterations 500 \
  -output_image out2.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn -cudnn_autotune'], shell=True, stdout=subprocess.PIPE)

# %%
process3 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out2.png \
  -style_scale $STYLE_SCALE \
  -print_iter 1 \
  -style_weight $STYLE_WEIGHT \
  -image_size 1024 \
  -num_iterations 200 \
  -output_image out3.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn -cudnn_autotune'], shell=True, stdout=subprocess.PIPE)

# %%
process4 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out3.png \
  -style_scale $STYLE_SCALE \
  -print_iter 1 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 200 \
  -output_image out4.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process5 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out4.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 500 \
  -output_image out5.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process6 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out5.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 500 \
  -output_image out6.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process7 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out6.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 500 \
  -output_image out7.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process8 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out7.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 500 \
  -output_image out8.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process9 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image {STYLE_IMAGE} \
  -init image -init_image out8.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1024 \
  -num_iterations 500 \
  -output_image out9.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
process10 = subprocess.Popen([f'python neural_style.py', '\
  -content_image {CONTENT_IMAGE} \
  -style_image $STYLE_IMAGE \
  -init image -init_image out9.png \
  -style_scale $STYLE_SCALE \
  -print_iter 10 \
  -style_weight $STYLE_WEIGHT2 \
  -image_size 1500 \
  -num_iterations 500 \
  -output_image surabaya_waveoff/out10.png \
  -tv_weight 0 \
  -gpu $GPU \
  -backend cudnn'], shell=True, stdout=subprocess.PIPE)

# %%
processes = [process1,
             process2,
             process3,
             process4,
             process5,
             process6,
             process7,
             process8,
             process9,
             process10]

# %%
for line in process.stdout: 
    sys.stdout.write(line)
# Out:
# VGG-19 Architecture Detected
# Successfully loaded models/vgg19-d01eb7cb.pth
# conv1_1: 64 3 3 3
# conv1_2: 64 64 3 3
# conv2_1: 128 64 3 3
# conv2_2: 128 128 3 3
# conv3_1: 256 128 3 3
# conv3_2: 256 256 3 3
# conv3_3: 256 256 3 3
# conv3_4: 256 256 3 3
# conv4_1: 512 256 3 3
# conv4_2: 512 512 3 3
# conv4_3: 512 512 3 3
# conv4_4: 512 512 3 3
# conv5_1: 512 512 3 3
# conv5_2: 512 512 3 3
# conv5_3: 512 512 3 3
# conv5_4: 512 512 3 3
# Setting up style layer 2: relu1_1
# Setting up style layer 7: relu2_1
# Setting up style layer 12: relu3_1
# Setting up style layer 21: relu4_1
# Setting up content layer 23: relu4_2
# Setting up style layer 30: relu5_1
# Capturing content targets
# nn.Sequential (
# ...
